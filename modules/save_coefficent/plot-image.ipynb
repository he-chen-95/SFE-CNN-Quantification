# %%
import numpy as np
import pandas as pd

file_w_1 = "coefficient_file/model-ckpt-8061/w_conv_1_v1.csv"
file_w_2 = "coefficient_file/model-ckpt-8061/w_conv_2_v2.csv"
w_conv_1 = pd.read_csv(file_w_1)
w_conv_2 = pd.read_csv(file_w_2)
w_conv_1.head(16)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.304390  0.117113 -0.274138 -0.449103 -0.300050  0.110247 -0.810396
# 1   0.011252 -0.060481  0.116625  0.097055 -0.086600 -0.023164 -0.059564
# 2  -0.318274 -0.365177 -0.209573 -0.147162 -0.061428 -0.298199 -0.356936
# 3  -0.044266  0.078163 -0.018236 -0.134377 -0.393291  0.082233  0.061303
# 4   0.181162  0.310691  0.245326  0.120314  0.090523  0.209837  0.122283
# 5  -0.201303 -0.250638 -0.019635  0.076974  0.114049 -0.249762 -0.093196
# 6  -0.006534 -0.231853 -0.358046 -0.317993 -0.120677  0.091575  0.064325
# 7  -0.043314 -0.042153  0.017021 -0.029476 -0.024973  0.023516  0.071214
# 8  -0.206958 -0.263949 -0.136696  0.034018  0.144593 -0.348061 -0.116254
# 9  -0.117779 -0.090499  0.162701  0.201988  0.160622  0.199211  0.317443
# 10  0.131682  0.266182  0.201780  0.052748 -0.000077  0.091980  0.201642
# 11  0.116347  0.206885  0.240050  0.132530  0.234343  0.238736  0.223571
# ...

# %% [markdown]
# ### w_conv_1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# column 0 distribution

w_conv_1.hist(column="0", bins=10, alpha=0.5)

# plt.hist(w_conv_1["0"], alpha=0.5)
# plt.show()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbfd5a074a8>]],
#       dtype=object)

# %%
# pandas.DataFrame.hist
# this function call matplotlib.pyplot.host() for each columns
hist = w_conv_1.hist(alpha=0.5, figsize=(24, 20), layout=(7,4), bins=20)

# %%
# hist = plt.hist(w_conv_1)

# %% [markdown]
# ### w_conv_2

# %%
# pandas.DataFrame.hist
# this function call matplotlib.pyplot.host() for each columns
hist = w_conv_2.hist(w_conv_1['0', '1', '2'], alpha=0.5, figsize=(24, 20), layout=(3,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Software/tensorflow/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('0', '1', '2')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-93c1f9cac697> in <module>
# ...

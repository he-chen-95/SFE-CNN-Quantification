# %%
import tensorflow as tf
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file
import os

model_dir = 'checkpoints/'
checkpoint_path = os.path.join(model_dir, "model.ckpt-9841")

# print all tensors in checkpoint file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='', all_tensors=True)
# Out:
# tensor_name:  b_conv_1
# [-0.03799224  0.05693392 -0.09345301  0.00807339  0.0411976   0.01726053
#  -0.04343693 -0.01495728 -0.1029233  -0.0025643  -0.14270632 -0.00795451
#   0.06142343 -0.04384959 -0.0748435  -0.08945771]
# tensor_name:  b_conv_1/Adam
# [-0.00389312 -0.00437228 -0.00255978  0.00792745 -0.0029789  -0.00177641
#   0.0003324  -0.0027463   0.0002155  -0.00018957 -0.00184728  0.00291365
#  -0.00368125 -0.00023098 -0.00098909  0.00052818]
# tensor_name:  b_conv_1/Adam_1
# [0.00028211 0.00133728 0.0005468  0.00606855 0.00135161 0.00106149
#  0.0002682  0.00023854 0.00019104 0.0003015  0.0001274  0.0002396
#  0.00207061 0.00031299 0.00046936 0.00012389]
# tensor_name:  b_conv_2
# [-0.08946034 -0.04031665  0.03395832 -0.05746221 -0.01244289  0.02260116
#  -0.09947123  0.02112235  0.01370952 -0.03227128 -0.15575998 -0.08355749
#  -0.05141661  0.03482426  0.02188972 -0.18026628 -0.06067039 -0.0876647
#  -0.13279487  0.01354537 -0.07263029 -0.1899191   0.04450511 -0.00484434
# ...

# %%
# print out all the tensors name
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='', all_tensors=False, all_tensor_names=True)
# Out:
# tensor_name:  b_conv_1
# tensor_name:  b_conv_1/Adam
# tensor_name:  b_conv_1/Adam_1
# tensor_name:  b_conv_2
# tensor_name:  b_conv_2/Adam
# tensor_name:  b_conv_2/Adam_1
# tensor_name:  b_fc_1
# tensor_name:  b_fc_1/Adam
# tensor_name:  b_fc_1/Adam_1
# tensor_name:  b_output_layer
# tensor_name:  b_output_layer/Adam
# tensor_name:  b_output_layer/Adam_1
# tensor_name:  optimizer_adam/beta1_power
# tensor_name:  optimizer_adam/beta2_power
# tensor_name:  w_conv_1
# tensor_name:  w_conv_1/Adam
# tensor_name:  w_conv_1/Adam_1
# tensor_name:  w_conv_2
# tensor_name:  w_conv_2/Adam
# tensor_name:  w_conv_2/Adam_1
# tensor_name:  w_fc_1
# tensor_name:  w_fc_1/Adam
# tensor_name:  w_fc_1/Adam_1
# tensor_name:  w_output_layer
# tensor_name:  w_output_layer/Adam
# tensor_name:  w_output_layer/Adam_1

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='w_conv_1', all_tensors=False)
# Out:
# tensor_name:  w_conv_1
# [[[[ 0.06585675  0.02840723  0.1195769   0.13416877  0.19234186
#      0.00694464 -0.14345284 -0.120944   -0.0164112  -0.15873998
#      0.03406112  0.07335247  0.0350442   0.0081662   0.06592208
#     -0.01182478]]
#
#   [[-0.05695412 -0.28443527  0.04539299  0.26196098  0.10220215
#      0.0185797  -0.08288165 -0.1507276  -0.08673017 -0.07013924
#      0.03062417 -0.00640021 -0.09956311  0.08028296  0.18767516
#     -0.13186786]]
#
#   [[ 0.05940281 -0.593399    0.06585251  0.22107057  0.23054883
#      0.10210016  0.08075003 -0.30685705 -0.01094743 -0.03969287
#      0.04050185 -0.15813288 -0.27464694  0.06637491  0.2807906
#     -0.10266828]]
#
#   [[-0.19619124 -0.34184197  0.02907974  0.23200205  0.17131811
#      0.03136094  0.12717758 -0.0981587   0.06359669  0.17460708
#     -0.1143911  -0.05870069 -0.19847569  0.15355314  0.3000488
#      0.03516302]]
#
#   [[-0.42434922 -0.10812801  0.09627929  0.23036292  0.08889766
# ...

# %% [markdown]
# structure of 'w_conv_1' tensor
# shape=(filter_height, filter_width, in_channels, out_channels)
# shape=(5,5,1,16)
#
# [
#
#     [
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#     ]
#
#     [
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#     ]
#
#     [
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#     ]
#
#     [
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#     ]
#
#     [
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#         [[ length = 16 ]]
#     ]
# ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='b_conv_1', all_tensors=False)
# Out:
# tensor_name:  b_conv_1
# [-0.03799224  0.05693392 -0.09345301  0.00807339  0.0411976   0.01726053
#  -0.04343693 -0.01495728 -0.1029233  -0.0025643  -0.14270632 -0.00795451
#   0.06142343 -0.04384959 -0.0748435  -0.08945771]

# %% [markdown]
# strcucture of 'b_conv_1' tensor
# shapr=(16,)
# [ length = 16 ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='w_conv_2', all_tensors=False)
# Out:
# tensor_name:  w_conv_2
# [[[[-2.50616223e-01 -9.39377919e-02 -1.52156755e-01 ...  2.14323431e-01
#     -2.67747846e-02  1.35652408e-01]
#    [-1.35819972e-01 -2.29455475e-02 -2.83656642e-02 ... -1.98624387e-01
#     -2.58683618e-02  2.93046609e-02]
#    [ 5.17009236e-02  2.01452062e-01  1.61695167e-01 ...  2.00474039e-02
#      1.89047195e-02  3.57626341e-02]
#    ...
#    [ 6.73763379e-02  2.15745807e-01  7.44360462e-02 ...  6.63041919e-02
#     -1.30689293e-01  9.27888155e-02]
#    [-8.72426257e-02 -2.25104224e-02 -8.26139972e-02 ...  1.82416886e-01
#      4.16721078e-03 -6.74366765e-03]
#    [-9.91833881e-02  7.55578140e-03 -3.53863724e-02 ... -5.40203713e-02
#     -1.53803006e-01 -1.87331755e-02]]
#
#   [[-1.04268072e-02 -1.22106403e-01 -2.19627455e-01 ...  1.43063247e-01
#     -1.53521493e-01  8.62536207e-03]
#    [-6.54150322e-02  1.85982604e-02 -5.58944166e-01 ...  4.39112366e-04
#     -1.22763505e-02  4.53768894e-02]
# ...

# %% [markdown]
# structure of 'w_conv_2' tensor
# shape=(5,5,16,36)
#
# [
#
#     [
#         [
#             [ length = 36 ]
#             [ length = 36 ]
#             [ length = 36 ]
#             ...共有16个
#         ]
#
#         [
#             [ length = 36 ]
#             [ length = 36 ]
#             [ length = 36 ]
#             ...共有16个
#         ]
#         ...共有5个
#     ]
#
#     [
#     ]
#
#     [
#     ]
#     ...共有5个
# ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='b_conv_2', all_tensors=False)
# Out:
# tensor_name:  b_conv_2
# [-0.08946034 -0.04031665  0.03395832 -0.05746221 -0.01244289  0.02260116
#  -0.09947123  0.02112235  0.01370952 -0.03227128 -0.15575998 -0.08355749
#  -0.05141661  0.03482426  0.02188972 -0.18026628 -0.06067039 -0.0876647
#  -0.13279487  0.01354537 -0.07263029 -0.1899191   0.04450511 -0.00484434
#  -0.03864813  0.01763436  0.00130625 -0.05388437 -0.02977033 -0.02569424
#   0.02061761 -0.09828648 -0.05886412 -0.07793635  0.02234108 -0.11940335]

# %% [markdown]
# strcucture of 'b_conv_1' tensor
# shapr=(128,)
# [ length = 36 ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='w_fc_1', all_tensors=False)
# Out:
# tensor_name:  w_fc_1
# [[ 0.06661767  0.17656544  0.0028651  ...  0.09223646 -0.08366428
#   -0.10988356]
#  [-0.01268718 -0.07350516 -0.04345614 ...  0.00148968 -0.01018895
#    0.02365572]
#  [-0.02381224  0.02212397 -0.06140342 ...  0.00518782  0.02132178
#   -0.08900863]
#  ...
#  [-0.04254918 -0.14790633  0.10551293 ... -0.06266373  0.01812446
#   -0.02818097]
#  [ 0.08482563 -0.05598486 -0.10053384 ...  0.00810942 -0.02619471
#    0.00538967]
#  [-0.00408412 -0.0840475  -0.09449076 ...  0.04089803 -0.0452648
#    0.04183712]]

# %% [markdown]
# structure of 'w_fc_1' tensor
# shape=(1764, 128)
#
# [
#
#     [ length = 128 ]
#     [ length = 128 ]
#     [ length = 128 ]
#     ...共有1764个
# ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='b_fc_1', all_tensors=False)
# Out:
# tensor_name:  b_fc_1
# [ 3.4417603e-02  9.8886406e-03 -4.1166607e-02 -1.5713293e-03
#   6.7532137e-02  4.9657270e-02  3.3091724e-02  6.9034815e-02
#   4.1455958e-02  2.7197940e-02  5.6623772e-02  8.0603696e-02
#  -8.6235348e-03  6.4395666e-02  1.4533317e-02  4.3873519e-02
#   1.1558114e-02  1.8998368e-02  2.4226969e-02  4.3579586e-02
#   3.1400353e-02 -8.7878155e-03  5.1076744e-02  1.7480813e-02
#   1.6271876e-02  1.5439135e-03  2.1844115e-02  1.0221789e-01
#   2.6972169e-02  3.4684654e-02  4.7568016e-02  6.9313040e-03
#   3.9727479e-02  8.4014714e-02  4.4897117e-02  4.8500816e-03
#   4.5817409e-02  1.2436419e-02  7.9229645e-02  6.0966577e-02
#   4.3390710e-02  2.0041490e-02  1.0221479e-01  6.0615785e-02
#   7.8232668e-02  2.0236488e-02  7.5147152e-02  3.6744513e-02
#  -2.5846066e-02  8.5423864e-02  2.5929501e-02 -4.7827060e-03
#   8.9355759e-02 -4.9530830e-02  1.5621690e-02  5.2784074e-02
#   3.6569629e-02  7.9163685e-02  2.2759313e-02  2.4338320e-02
# ...

# %% [markdown]
# strcucture of 'b_fc_1' tensor
# shapr=(128,)
# [ length = 128 ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='w_output_layer', all_tensors=False)

# %% [markdown]
# structure of 'w_fc_1' tensor
# shape=(128, 10)
#
# [
#
#     [ length = 10 ]
#     [ length = 10 ]
#     [ length = 10 ]
#     ...共有128个
# ]

# %%
# print only tensor "tensor_name" in ckeck point file
print_tensors_in_checkpoint_file(file_name=checkpoint_path, tensor_name='b_output_layer', all_tensors=False)

# %% [markdown]
# strcucture of 'b_fc_1' tensor
# shapr=(10,)
# [ length = 10 ]

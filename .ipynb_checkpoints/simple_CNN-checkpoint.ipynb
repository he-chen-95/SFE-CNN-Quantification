# %%
import tensorflow as tf

print("tensorflow version:",tf.__version__)
# Out:
# tensorflow version: 1.12.0

# %%
# load dataset

from modules.mnist import MNIST
data = MNIST(data_dir="data/MNIST")

print("Size of:")
print("    -Training-set:\t\t{}".format(data.num_train))
print("    -Validation-set:\t\t{}".format(data.num_val))
print("    -Test-set:\t\t\t{}".format(data.num_test))

# mnist images width and height: 28
img_size = data.img_size
# mnist data input (image shape: 28 * 28 = 784)
img_shape = data.img_shape
img_size_flat = data.img_size_flat
# mnist gray scale images with 1 channel
num_channels = data.num_channels
# mnist total classes(0-9 digits)
num_classes = data.num_classes


print("\ndata set information:")
print("    -img_size:\t\t\t", img_size)
print("    -img_shape:\t\t\t", img_shape)
print("    -num_channels:\t\t", num_channels)
print("    -img_size_flat:\t\t", img_size_flat)
print("    -num_classes:\t\t", num_classes)
# Out:
# Size of:
#     -Training-set:		55000
#     -Validation-set:		5000
#     -Test-set:			10000
#
# data set information:
#     -img_size:			 28
#     -img_shape:			 (28, 28)
#     -num_channels:		 1
#     -img_size_flat:		 784
#     -num_classes:		 10

# %%
# Training Parameters
learning_rate_1 = 1e-3
display_step = 20

train_batch_size_1 = 64
train_batch_size_2 = 128

# Dropout probability to keep units
dropout_prob_1 = 0.75

# L2 正则项系数
BETA = 0.01

# %%
# network parameters

# convolutional layer 1
size_conv_kernel_1 = 5
num_conv_kernel_1 = 16

# convolutional layer 2
size_conv_kernel_2 = 5
num_conv_kernel_2 = 36

# fully connected layer 1
# we do the pooling operations 2 times
num_pooling = 2
# fully connected layer, 7*7*36=1764 input size
size_input_fc_1 = int((img_size/(2*num_pooling))*(img_size/(2*num_pooling))*(num_conv_kernel_2))
# size of fc layer 1
size_fc_1 = 128

# fully connected layer 2 as output layer
size_output = num_classes

# %% [markdown]
# Layer definiton

# %%
shape_dict = {
    #shape of weights
    
    # 5*5 conv, 1 input channel, 16 output channel.
    's_weights_conv_1':[size_conv_kernel_1, size_conv_kernel_1, num_channels, num_conv_kernel_1],
    # 5*5 conv, 16 input channel, 36 output channel.
    's_weights_conv_2':[size_conv_kernel_2, size_conv_kernel_2, num_conv_kernel_1, num_conv_kernel_2],
    # faltten layer, convolutional layer output 4D tensors. 
    # we now wish to use these as input in a fully connected network, 
    # which requires for the tensors to be reshaped or flattened to 2D tensors.
    # fully connected layer, 7*7*36=1764 inputs, 128 outputs
    's_weights_fc_1':[size_input_fc_1, size_fc_1],
    # fully connected layer, 128 inputs, 10 outputs(class prediction)
    's_weights_output_layer':[size_fc_1, num_classes],
    
    # shape of biases
    
    's_biases_conv_1':[num_conv_kernel_1],
    's_biases_conv_2':[num_conv_kernel_2],
    's_biases_fc_1':[size_fc_1],
    's_biases_output_layer':[size_output]
}

weights_dict = {
    
    # we add the name atrribute for tf.name_scope(). you find it in cnn_modules.py
    'w_conv_1': tf.Variable(tf.truncated_normal(shape_dict['s_weights_conv_1'], stddev=0.05), 
                            name="w_conv_1"),
    # 'w_conv_1': tf.Variable(tf.random_normal(shape_dict['s_weights_conv_1']))
    # 'w_conv_1': tf.Variable(tf.zeros(shape_dict['s_weights_conv_1'])
    
    'w_conv_2': tf.Variable(tf.truncated_normal(shape_dict['s_weights_conv_2'], stddev=0.05), 
                            name="w_conv_2"),
    # 'w_conv_2': tf.Variable(tf.random_normal(shape_dict['s_weights_conv_2'])),
    
    'w_fc_1': tf.Variable(tf.truncated_normal(shape_dict['s_weights_fc_1'], stddev=0.05), 
                          name="w_fc_1"),
    # 'w_fc_1': tf.Variable(tf.random_normal(shape_dict['s_weights_fc_1'])),
    
    'w_output_layer': tf.Variable(tf.truncated_normal(shape_dict['s_weights_output_layer'], stddev=0.05), 
                                  name="w_output_layer")
    # 'w_output_layer': tf.Variable(tf.random_normal(shape_dict['s_weights_output_layer']))
}

biases_dict = {
    # 'b_conv_1': tf.Variable(tf.random_normal(shape_dict['s_biases_conv_1'])),
    'b_conv_1': tf.Variable(tf.constant(0.05, shape=shape_dict['s_biases_conv_1']),
                            name="b_conv_1"),
    
    # 'b_conv_2': tf.Variable(tf.random_normal(shape_dict['s_biases_conv_2'])),
    'b_conv_2': tf.Variable(tf.constant(0.05, shape=shape_dict['s_biases_conv_2']),
                            name="b_conv_2"),
    
    # 'b_fc_1': tf.Variable(tf.random_normal(shape_dict['s_biases_fc_1'])),
    'b_fc_1': tf.Variable(tf.constant(0.05, shape=shape_dict['s_biases_fc_1']),
                          name="b_fc_1"),
    
    # 'b_output_layer': tf.Variable(tf.random_normal(shape_dict['s_biases_output_layer']))
    'b_output_layer': tf.Variable(tf.constant(0.05, shape=shape_dict['s_biases_output_layer']),
                                  name="b_output_layer")
}

#print("weights shape of conv1 layer:']:", shape_dict['s_weights_conv_1'])
#print("biases shape of conv1 layer:", shape_dict['s_biases_conv_1'])
print("w_conv_1:", weights_dict['w_conv_1'])
print("w_conv_2:", weights_dict['w_conv_2'])
print("w_fc_1:", weights_dict['w_fc_1'])
print("w_output_layer:", weights_dict['w_output_layer'])
print("b_conv_1:", biases_dict['b_conv_1'])
print("b_conv_2:", biases_dict['b_conv_2'])
print("b_fc_1:", biases_dict['b_fc_1'])
print("b_output_layer:", biases_dict['b_output_layer'])
# Out:
# w_conv_1: <tf.Variable 'w_conv_1:0' shape=(5, 5, 1, 16) dtype=float32_ref>
# w_conv_2: <tf.Variable 'w_conv_2:0' shape=(5, 5, 16, 36) dtype=float32_ref>
# w_fc_1: <tf.Variable 'w_fc_1:0' shape=(1764, 128) dtype=float32_ref>
# w_output_layer: <tf.Variable 'w_output_layer:0' shape=(128, 10) dtype=float32_ref>
# b_conv_1: <tf.Variable 'b_conv_1:0' shape=(16,) dtype=float32_ref>
# b_conv_2: <tf.Variable 'b_conv_2:0' shape=(36,) dtype=float32_ref>
# b_fc_1: <tf.Variable 'b_fc_1:0' shape=(128,) dtype=float32_ref>
# b_output_layer: <tf.Variable 'b_output_layer:0' shape=(10,) dtype=float32_ref>

# %%
from modules.cnn_modules import new_conv_layer
from modules.cnn_modules import flatten_layer
from modules.cnn_modules import new_fc_layer
from modules.cnn_modules import new_dropout_layer

def conv_net(input, weights, biases, dropout_prob):
    
    # convolutional layer 1
    # name="layer_conv_1" means that we use it as the name node in tensorboard.
    layer_conv_1 = \
        new_conv_layer(input=x_image,
                       layer_name="layer_conv_1",
                       weights=weights_dict['w_conv_1'],
                       biases=biases_dict['b_conv_1'],
                       use_pooling=True)
    print("layer_conv_1:", layer_conv_1)
    
    # convolutional layer 2
    layer_conv_2 = \
        new_conv_layer(input=layer_conv_1,
                       layer_name="layer_conv_2",
                       weights=weights_dict['w_conv_2'],
                       biases=biases_dict['b_conv_2'],
                       use_pooling=True)
    print("layer_conv_2:", layer_conv_2)
    
    # flatten layer
    layer_flat = flatten_layer(layer_conv_2, layer_name="flatten_layer")
    print("layer_flat:",layer_flat)
    
    # fully-connected layer 1
    layer_fc_1 = new_fc_layer(input=layer_flat,
                              layer_name="layer_fc_1",
                              weights=weights_dict['w_fc_1'],
                              biases=biases_dict['b_fc_1'],
                              use_relu=True)
    print("layer_fc_1:", layer_fc_1)

    # fully-connected layer 2, output layer. relu is used,
    # so we can learn non-linear relations
    #layer_fc_2 = new_fc_layer(input=layer_fc_1,
    #                          layer_name="layer_fc_2",
    #                          weights=weights_dict['w_output_layer'],
    #                          biases=biases_dict['b_output_layer'],
    #                          use_relu=False)
    #print("layer_fc2:", layer_fc_2)
        
    # apply dropout layer as output layer
    layer_dropout = new_dropout_layer(input=layer_fc_1,
                                      layer_name="layer_dropout",
                                      weights=weights_dict['w_output_layer'],
                                      biases=biases_dict['b_output_layer'],
                                      dropout=dropout_prob)
    print("layer_dropout:", layer_dropout)
    
    layer_output = layer_dropout

    return layer_output

# %% [markdown]
# Feed-word Setup

# %%
# Setup placeholders, add name nodes for tensorboard
# placeholder作为输入节点， Variable作为参数节点， Conv2d作为运算节点
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x_input_data')    
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_label_data')
# prediction result
y_true_cls = tf.argmax(y_true, axis=1)
# dropout (keep probability)
keep_prob = tf.placeholder(tf.float32)

print("x:", x)
# one-hot code output
print("y_true:", y_true)
print("y_true_cls:", y_true_cls)
print("dropout probability:", keep_prob)
# Out:
# x: Tensor("x_input_data:0", shape=(?, 784), dtype=float32)
# y_true: Tensor("y_label_data:0", shape=(?, 10), dtype=float32)
# y_true_cls: Tensor("ArgMax:0", shape=(?,), dtype=int64)
# dropout probability: Tensor("Placeholder:0", dtype=float32)

# %%
# softmax layer
# mnist data input is a 1D vector with length 784(28 * 28 pixels)
# reshape to match picture format [height * width * channel]
# tensor input become 4D: [batch_size, height, width, channel]
# -1 means: num_images/batch_size will be calculate automatically    
# reshpe the data
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])
print("x_image:", x_image)
# collect some summaries for tensorboard
tf.summary.image('input_images', x_image, 9)

# create the network
output_layer = conv_net(input=x_image, 
                        weights=weights_dict, 
                        biases=biases_dict, 
                        dropout_prob=dropout_prob_1)

print("output_layer:", output_layer)

with tf.name_scope("softmax"):
    # CNN_model
    y_pred = tf.nn.softmax(output_layer)    
print("y_pred:", y_pred)

y_pred_cls = tf.argmax(y_pred, axis=1)
print("y_pred_cls:", y_pred_cls)
# Out:
# x_image: Tensor("Reshape:0", shape=(?, 28, 28, 1), dtype=float32)
# layer_conv_1: Tensor("layer_conv_1/relu:0", shape=(?, 14, 14, 16), dtype=float32)
# layer_conv_2: Tensor("layer_conv_2/relu:0", shape=(?, 7, 7, 36), dtype=float32)
# layer_flat: Tensor("flatten_layer/flatten:0", shape=(?, 1764), dtype=float32)
# layer_fc_1: Tensor("layer_fc_1/relu:0", shape=(?, 128), dtype=float32)
# layer_dropout: Tensor("layer_dropout/w_plus_b:0", shape=(?, 10), dtype=float32)
# output_layer: Tensor("layer_dropout/w_plus_b:0", shape=(?, 10), dtype=float32)
# y_pred: Tensor("softmax/Softmax:0", shape=(?, 10), dtype=float32)
# y_pred_cls: Tensor("ArgMax_1:0", shape=(?,), dtype=int64)

# %% [markdown]
# Loss & Traing

# %%
# Compute cross entropy as our loss function
# cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=output_layer,
#                                                           labels=y_true)
# print("cross_entropy:", cross_entropy)
# cross_entropy: Tensor("softmax_cross_entropy_with_logits/Reshape_2:0", shape=(?,), dtype=float32)

# 模型参数，包括 weight 和 bias
#trainable_vars = tf.trainable_variables()

# add name scope for tensorboard
with tf.name_scope("cost"):
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=output_layer, labels=y_true))
    # L2正则化效果不好，accuracy~=97.0%
    #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=output_layer, labels=y_true))+\
    #    BETA * tf.add_n([tf.nn.l2_loss(v)
    #                     for v in trainable_vars if not 'b' in v.name])
    
    # create a summary to monitor cost tensor on tensorboard
    tf.summary.scalar('cross_entropy', cost)

print("cost:", cost)
# Out:
# cost: Tensor("cost/Mean:0", shape=(), dtype=float32)

# %%
# add name scope for tensorboard
# use an AdamOptimizer to train the network
with tf.name_scope("optimizer_adam"):
    # optimization algorithm
    optimizer_adam = tf.train.AdamOptimizer(learning_rate=learning_rate_1).minimize(cost)
    # Gradiebt Descent
    #optimizer = tf.train.GradientDescentOptimizer(learning_rate_1)
    # Op to calculate every variable gradient
    #grads = tf.gradients(cost, tf.trainable_variable())
    #grads = list(zip(grads, tf.trainable_variable()))
    # Op to update all variables according to their gradients
    #apply_grads = optimizer.apply_gradients(grads_and_vars=grads)
    
# optimizer_gradientDescent = tf.train.GradientDescentOptimizer(learning_rate=learning_rate_1).minimize(cost)

# now we use AdamOptimizer
optimizer = optimizer_adam

print("optimizer:", optimizer)
# Out:
# optimizer: name: "optimizer_adam/Adam"
# op: "NoOp"
# input: "^optimizer_adam/Adam/update_w_conv_1/ApplyAdam"
# input: "^optimizer_adam/Adam/update_w_conv_2/ApplyAdam"
# input: "^optimizer_adam/Adam/update_w_fc_1/ApplyAdam"
# input: "^optimizer_adam/Adam/update_w_output_layer/ApplyAdam"
# input: "^optimizer_adam/Adam/update_b_conv_1/ApplyAdam"
# input: "^optimizer_adam/Adam/update_b_conv_2/ApplyAdam"
# input: "^optimizer_adam/Adam/update_b_fc_1/ApplyAdam"
# input: "^optimizer_adam/Adam/update_b_output_layer/ApplyAdam"
# input: "^optimizer_adam/Adam/Assign"
# input: "^optimizer_adam/Adam/Assign_1"

# %%
# add name scope for tensorboard
# compute the accuracy
with tf.name_scope("accuracy"):
    # 1D tensor of type bool 
    correct_prediction = tf.equal(y_pred_cls, y_true_cls)
    # cast the "correct_prediction" to type float32, then calculate the mean
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    # createb a summary to monitor accuracy tensor on tensorboard
    tf.summary.scalar('accuracy', accuracy)
    
print("correct_prediction:", correct_prediction)
print("accuracy:", accuracy)
# Out:
# correct_prediction: Tensor("accuracy/Equal:0", shape=(?,), dtype=bool)
# accuracy: Tensor("accuracy/Mean:0", shape=(), dtype=float32)

# %% [markdown]
# Train the model

# %%
import os
# "0,1,2" -> use the '/gpu:0' '/gpu:1' '/gpu:2'.
# "" -> no GPU visiable 
os.environ["CUDA_VISIBLE_DEVICES"]='0'
config = tf.ConfigProto()
# program can only occupy up to 90% gpu memory of '/gpu:0'
config.gpu_options.per_process_gpu_memory_fraction = 0.9
# program apply memory on demande
config.gpu_options.allow_growth = True
# to find out which devices your operations and tensors are assigned to,
# create a session with 'log_device_placement' configuration option set to True.
config.log_device_placement=True

session = tf.Session(config=config)

# %%
# initialize all the virables
def init_variables():
    session.run(tf.global_variables_initializer())

# execute the function to initialize the variables
init_variables()

# create summaries to visualize weights
#for var in tf.trainable_variables():
#    tf.summary.histogram(var.name, var)

#  summarize all gradients
#for grad, var in grads:
#    tf.summary.histogram(var.name+"/gradient", grad)

# %%
# LOGDIR = BASEDIR + 'lr={:.0E},bs={}'.format(learning_rate, batch_size)
    
# tensorboard collect the summaries
logs_path = "logs/simple_cnn/2019-03-27"
# merge all summary into a single op
merged_summary = tf.summary.merge_all()
# write logs to tensorboard
writer = tf.summary.FileWriter(logs_path, session.graph)
# writer.add_graph(tf_session.graph)

# %%
# test plot images function
# from modules.plot_functions import plot_images

# test the plot_images() funnction
# images = data.x_test[0:9]
# cls_true = data.y_test_cls[0:9]
# plot_images(images=images, cls_true=cls_true)

# %%
#from modules.predict_functions import predict_cls_test
#from modules.predict_functions import predict_cls_validation

#predict_cls_test(tf_session=session,
#                 x_ph=x,
#                 y_true_ph=y_true,
#                 keep_prob_ph=keep_prob,
#                 y_pred_cls_tensor = y_pred_cls)

#predict_cls_validation(tf_session=session,
#                       x_ph=x,
#                       y_true_ph=y_true,
#                       keep_prob_ph=keep_prob,
#                       y_pred_cls_tensor=y_pred_cls)

# %%
# function for saving files during optimization iterations
# overwrite the saving file when we get a better accuracy
import tensorflow as tf
import os

save_dir = 'checkpoints/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
model_path = os.path.join(save_dir, 'model.ckpt')
print("model_path:", model_path)

saver = tf.train.Saver(max_to_keep=5)
# Out:
# model_path: checkpoints/model.ckpt

# %% [markdown]
# #### accuracy before any optimization

# %%
# %matplotlib inline

from modules.predict_functions import print_test_accuracy

# calculate the predicted class for the test-set
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:10.6% (1058 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[ 53   0  92   5 711   0   9  41  24  45]
#  [101   0  90   4 713   0  21  45  78  83]
#  [ 79   0 107   5 677   0   8  18  65  73]
#  [ 82   0 134   5 578   1   8  73  26 103]
#  [ 30   0  87   6 708   0   8  41  67  35]
#  [ 80   0  87   6 593   0  10  49  28  39]
#  [ 24   0  49   1 802   1   8  13  28  32]
#  [ 69   0  60  16 663   0   4  66  61  89]
#  [ 99   0  96   3 613   1  12  27  50  73]
#  [ 71   1  92   4 636   1   4  57  82  61]]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### performace after 1 optimization  iteration

# %%
from modules.predict_functions import optimize

#def main():
#    for lr in [1e-2, 1e-3, 1e-4]:
#        for bs in [64, 128]:
#            logging.info('learing rate = {:.0E}, batch size = {}'.format(lr, bs))
#cifar10_model(lr, bs)

# get the save path returned by saver.save() in optimization() methode
save_path = optimize(tf_session=session,
                 tf_saver=saver,
                 tensorboard_summary=merged_summary,
                 tensorboard_writer=writer,    
                 model_path=model_path,
                 x_ph=x,
                 y_true_ph=y_true,
                 keep_prob_ph=keep_prob,
                 y_pred_cls_tensor=y_pred_cls,
                 optimizer=optimizer, 
                 display_step = display_step,
                 num_iterations=1, 
                 loss_opt = cost,
                 accuracy = accuracy,
                 dropout_prob=dropout_prob_1)
# Out:
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1
# Optimization Iteration:      1, Minibatch Loss:2.2552, Training-Batch Accuracy:  17.2%, Validation Accuracy: 10.5% *
# Time usage:0:00:00

# %%
from modules.predict_functions import print_test_accuracy

print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_example_error=True,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:10.2% (1023 / 10000)
# Example errors for test-set:
#     predicted classes:	 [4 4 4 ... 4 4 4]
#     correct:		 [False False False ...  True False False]
#     incorrect:		 [ True  True  True ... False  True  True]
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[   0    0    5    0  958    0    0    0    0   17]
#  [   0    2    5    0 1040    0    0    0    3   85]
#  [   0    0   16    0  948    0    0    0    2   66]
#  [   2    1   23    0  899    0    0    0    0   85]
#  [   0    0    5    0  960    0    0    0    0   17]
#  [   1    0    7    0  849    0    0    0    0   35]
#  [   0    0    3    0  942    1    0    0    0   12]
#  [   0    0    5    0  957    0    0    0    1   65]
#  [   0    0    9    0  906    0    0    0    3   56]
#  [   0    0    5    0  961    0    0    0    1   42]]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### performace after 100 optimization  iteration

# %%
optimize(tf_session=session,
         tf_saver=saver,
         tensorboard_summary=merged_summary,
         tensorboard_writer=writer,
         model_path=model_path,
         x_ph=x,
         y_true_ph=y_true,
         keep_prob_ph=keep_prob,
         y_pred_cls_tensor=y_pred_cls,
         optimizer=optimizer, 
         display_step = display_step,
         num_iterations=99, 
         loss_opt = cost,
         accuracy = accuracy,
         dropout_prob=dropout_prob_1)
# Out:
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-21
# Optimization Iteration:     21, Minibatch Loss:1.7439, Training-Batch Accuracy:  64.1%, Validation Accuracy: 48.4% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-41
# Optimization Iteration:     41, Minibatch Loss:0.7502, Training-Batch Accuracy:  76.6%, Validation Accuracy: 76.3% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-61
# Optimization Iteration:     61, Minibatch Loss:0.6807, Training-Batch Accuracy:  78.1%, Validation Accuracy: 85.0% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-81
# Optimization Iteration:     81, Minibatch Loss:0.5257, Training-Batch Accuracy:  87.5%, Validation Accuracy: 88.0% *
# Time usage:0:00:02
# 'checkpoints/model.ckpt-81'

# %%
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:88.6% (8862 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[ 953    0    3    4    0    7    7    1    5    0]
#  [   0 1092    1    6    2    4    7    0   23    0]
#  [  19    2  899   34   18    4   15   10   26    5]
#  [   5    1   17  882    2   44    5   16   25   13]
#  [   1    1    4    0  896    1   16    1    2   60]
#  [  17    1    5   50   14  761   18    1   20    5]
#  [  16    1    3    1   13   24  897    0    3    0]
#  [   2   12   38    7    7    2    0  857    7   96]
#  [  16    8   11   31   20   56   17   10  782   23]
#  [  10    5   11   15   88    4    0   20   13  843]]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### performace after 1000 optimization  iteration

# %%
optimize(tf_session=session,
         tf_saver=saver,
         tensorboard_summary=merged_summary,
         tensorboard_writer=writer,
         model_path=model_path,
         x_ph=x,
         y_true_ph=y_true,
         keep_prob_ph=keep_prob,
         y_pred_cls_tensor=y_pred_cls,
         optimizer=optimizer, 
         display_step = display_step,
         num_iterations=900, 
         loss_opt = cost,
         accuracy = accuracy,
         dropout_prob=dropout_prob_1)
# Out:
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-101
# Optimization Iteration:    101, Minibatch Loss:0.4748, Training-Batch Accuracy:  85.9%, Validation Accuracy: 90.7% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-121
# Optimization Iteration:    121, Minibatch Loss:0.2665, Training-Batch Accuracy:  92.2%, Validation Accuracy: 91.5% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-141
# Optimization Iteration:    141, Minibatch Loss:0.3111, Training-Batch Accuracy:  89.1%, Validation Accuracy: 93.0% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-161
# Optimization Iteration:    161, Minibatch Loss:0.4779, Training-Batch Accuracy:  82.8%, Validation Accuracy: 93.1% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-181
# Optimization Iteration:    181, Minibatch Loss:0.1500, Training-Batch Accuracy:  96.9%, Validation Accuracy: 94.5% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-201
# Optimization Iteration:    201, Minibatch Loss:0.1750, Training-Batch Accuracy:  93.8%, Validation Accuracy: 95.3% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-221
# Optimization Iteration:    221, Minibatch Loss:0.1933, Training-Batch Accuracy:  95.3%, Validation Accuracy: 95.4% *
# predicted classes for validation-set:
# Optimization Iteration:    241, Minibatch Loss:0.1937, Training-Batch Accuracy:  96.9%, Validation Accuracy: 95.3%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-261
# Optimization Iteration:    261, Minibatch Loss:0.0787, Training-Batch Accuracy:  98.4%, Validation Accuracy: 96.1% *
# predicted classes for validation-set:
# Optimization Iteration:    281, Minibatch Loss:0.1882, Training-Batch Accuracy:  93.8%, Validation Accuracy: 95.6%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-301
# Optimization Iteration:    301, Minibatch Loss:0.0637, Training-Batch Accuracy:  98.4%, Validation Accuracy: 96.4% *
# predicted classes for validation-set:
# Optimization Iteration:    321, Minibatch Loss:0.0232, Training-Batch Accuracy: 100.0%, Validation Accuracy: 96.3%
# predicted classes for validation-set:
# Optimization Iteration:    341, Minibatch Loss:0.1527, Training-Batch Accuracy:  93.8%, Validation Accuracy: 96.3%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-361
# Optimization Iteration:    361, Minibatch Loss:0.2539, Training-Batch Accuracy:  95.3%, Validation Accuracy: 96.4% *
# predicted classes for validation-set:
# Optimization Iteration:    381, Minibatch Loss:0.1640, Training-Batch Accuracy:  93.8%, Validation Accuracy: 96.1%
# predicted classes for validation-set:
# Optimization Iteration:    401, Minibatch Loss:0.3016, Training-Batch Accuracy:  95.3%, Validation Accuracy: 96.3%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-421
# Optimization Iteration:    421, Minibatch Loss:0.3936, Training-Batch Accuracy:  95.3%, Validation Accuracy: 96.7% *
# predicted classes for validation-set:
# Optimization Iteration:    441, Minibatch Loss:0.1576, Training-Batch Accuracy:  93.8%, Validation Accuracy: 96.4%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-461
# Optimization Iteration:    461, Minibatch Loss:0.0350, Training-Batch Accuracy: 100.0%, Validation Accuracy: 96.8% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-481
# Optimization Iteration:    481, Minibatch Loss:0.1710, Training-Batch Accuracy:  95.3%, Validation Accuracy: 96.9% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-501
# Optimization Iteration:    501, Minibatch Loss:0.0146, Training-Batch Accuracy: 100.0%, Validation Accuracy: 97.2% *
# predicted classes for validation-set:
# Optimization Iteration:    521, Minibatch Loss:0.0542, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.2%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-541
# Optimization Iteration:    541, Minibatch Loss:0.0698, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.3% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-561
# Optimization Iteration:    561, Minibatch Loss:0.0445, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.5% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-581
# Optimization Iteration:    581, Minibatch Loss:0.0485, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.7% *
# predicted classes for validation-set:
# Optimization Iteration:    601, Minibatch Loss:0.0551, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.0%
# predicted classes for validation-set:
# Optimization Iteration:    621, Minibatch Loss:0.1253, Training-Batch Accuracy:  95.3%, Validation Accuracy: 97.4%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-641
# Optimization Iteration:    641, Minibatch Loss:0.1251, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.8% *
# predicted classes for validation-set:
# Optimization Iteration:    661, Minibatch Loss:0.2239, Training-Batch Accuracy:  92.2%, Validation Accuracy: 97.7%
# predicted classes for validation-set:
# Optimization Iteration:    681, Minibatch Loss:0.1876, Training-Batch Accuracy:  93.8%, Validation Accuracy: 97.5%
# predicted classes for validation-set:
# Optimization Iteration:    701, Minibatch Loss:0.3588, Training-Batch Accuracy:  92.2%, Validation Accuracy: 97.4%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-721
# Optimization Iteration:    721, Minibatch Loss:0.1078, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.2% *
# predicted classes for validation-set:
# Optimization Iteration:    741, Minibatch Loss:0.0485, Training-Batch Accuracy: 100.0%, Validation Accuracy: 97.9%
# predicted classes for validation-set:
# Optimization Iteration:    761, Minibatch Loss:0.0187, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.2%
# predicted classes for validation-set:
# Optimization Iteration:    781, Minibatch Loss:0.1270, Training-Batch Accuracy:  93.8%, Validation Accuracy: 97.8%
# predicted classes for validation-set:
# Optimization Iteration:    801, Minibatch Loss:0.0711, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:    821, Minibatch Loss:0.0524, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.0%
# predicted classes for validation-set:
# Optimization Iteration:    841, Minibatch Loss:0.0977, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.9%
# predicted classes for validation-set:
# Optimization Iteration:    861, Minibatch Loss:0.0493, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.7%
# predicted classes for validation-set:
# Optimization Iteration:    881, Minibatch Loss:0.0636, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.8%
# predicted classes for validation-set:
# Optimization Iteration:    901, Minibatch Loss:0.0867, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.9%
# predicted classes for validation-set:
# Optimization Iteration:    921, Minibatch Loss:0.0391, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.9%
# predicted classes for validation-set:
# Optimization Iteration:    941, Minibatch Loss:0.0591, Training-Batch Accuracy:  98.4%, Validation Accuracy: 97.6%
# predicted classes for validation-set:
# Optimization Iteration:    961, Minibatch Loss:0.0614, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:    981, Minibatch Loss:0.0245, Training-Batch Accuracy: 100.0%, Validation Accuracy: 97.6%
# Time usage:0:00:14
# 'checkpoints/model.ckpt-721'

# %%
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:97.9% (9787 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[ 972    0    0    0    0    0    4    0    3    1]
#  [   0 1127    2    0    0    0    4    0    2    0]
#  [   2    2 1018    2    1    0    0    3    4    0]
#  [   1    1    4  996    0    0    0    2    2    4]
#  [   0    1    2    0  967    0    4    2    2    4]
#  [   4    1    0   13    0  863    4    1    4    2]
#  [   5    3    1    0    2    0  945    0    2    0]
#  [   1    5   11    5    3    0    0  985    1   17]
#  [  13    1    7    1    3    1    8    1  934    5]
#  [   5    4    0    3    6    0    0    6    5  980]]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### performace after 10000 optimization  iteration

# %%
optimize(tf_session=session,
         tf_saver=saver,
         tensorboard_summary=merged_summary,
         tensorboard_writer=writer,
         model_path=model_path,
         x_ph=x,
         y_true_ph=y_true,
         keep_prob_ph=keep_prob,
         y_pred_cls_tensor=y_pred_cls,
         optimizer=optimizer, 
         display_step = display_step,
         num_iterations=9000, 
         loss_opt = cost,
         accuracy = accuracy,
         dropout_prob=dropout_prob_1)
# Out:
# predicted classes for validation-set:
# Optimization Iteration:   1001, Minibatch Loss:0.0137, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:   1021, Minibatch Loss:0.0845, Training-Batch Accuracy:  96.9%, Validation Accuracy: 97.8%
# predicted classes for validation-set:
# Optimization Iteration:   1041, Minibatch Loss:0.1184, Training-Batch Accuracy:  93.8%, Validation Accuracy: 98.2%
# predicted classes for validation-set:
# Optimization Iteration:   1061, Minibatch Loss:0.0381, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.2%
# predicted classes for validation-set:
# Optimization Iteration:   1081, Minibatch Loss:0.0687, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.2%
# predicted classes for validation-set:
# Optimization Iteration:   1101, Minibatch Loss:0.0690, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.2%
# predicted classes for validation-set:
# Optimization Iteration:   1121, Minibatch Loss:0.1423, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:   1141, Minibatch Loss:0.1053, Training-Batch Accuracy:  96.9%, Validation Accuracy: 97.8%
# predicted classes for validation-set:
# Optimization Iteration:   1161, Minibatch Loss:0.0457, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:   1181, Minibatch Loss:0.0357, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1201
# Optimization Iteration:   1201, Minibatch Loss:0.0552, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4% *
# predicted classes for validation-set:
# Optimization Iteration:   1221, Minibatch Loss:0.0753, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.3%
# predicted classes for validation-set:
# Optimization Iteration:   1241, Minibatch Loss:0.1030, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.0%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1261
# Optimization Iteration:   1261, Minibatch Loss:0.0429, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4% *
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1281
# Optimization Iteration:   1281, Minibatch Loss:0.0655, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5% *
# predicted classes for validation-set:
# Optimization Iteration:   1301, Minibatch Loss:0.0170, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1321
# Optimization Iteration:   1321, Minibatch Loss:0.0149, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7% *
# predicted classes for validation-set:
# Optimization Iteration:   1341, Minibatch Loss:0.0681, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1361, Minibatch Loss:0.0619, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1381, Minibatch Loss:0.1623, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.3%
# predicted classes for validation-set:
# Optimization Iteration:   1401, Minibatch Loss:0.0520, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1421, Minibatch Loss:0.0135, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1441, Minibatch Loss:0.0112, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1461, Minibatch Loss:0.1064, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1481, Minibatch Loss:0.0614, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1501, Minibatch Loss:0.0252, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.3%
# predicted classes for validation-set:
# Optimization Iteration:   1521, Minibatch Loss:0.0319, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1541, Minibatch Loss:0.0689, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1561, Minibatch Loss:0.0496, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1581, Minibatch Loss:0.1932, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   1601, Minibatch Loss:0.0257, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1621, Minibatch Loss:0.1084, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1641, Minibatch Loss:0.0744, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.3%
# predicted classes for validation-set:
# Optimization Iteration:   1661, Minibatch Loss:0.0750, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1681, Minibatch Loss:0.0369, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1701, Minibatch Loss:0.0267, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1721, Minibatch Loss:0.0361, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1741, Minibatch Loss:0.0439, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   1761, Minibatch Loss:0.0092, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1781, Minibatch Loss:0.0034, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   1801, Minibatch Loss:0.0154, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1821, Minibatch Loss:0.0156, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1841
# Optimization Iteration:   1841, Minibatch Loss:0.0608, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.8% *
# predicted classes for validation-set:
# Optimization Iteration:   1861, Minibatch Loss:0.0564, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-1881
# Optimization Iteration:   1881, Minibatch Loss:0.0242, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8% *
# predicted classes for validation-set:
# Optimization Iteration:   1901, Minibatch Loss:0.0459, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   1921, Minibatch Loss:0.0129, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1941, Minibatch Loss:0.0408, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1961, Minibatch Loss:0.0084, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   1981, Minibatch Loss:0.0416, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2001, Minibatch Loss:0.0161, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2021, Minibatch Loss:0.0372, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2041, Minibatch Loss:0.0120, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2061, Minibatch Loss:0.0863, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2081, Minibatch Loss:0.0389, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2101, Minibatch Loss:0.0212, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2121, Minibatch Loss:0.0696, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2141, Minibatch Loss:0.0479, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   2161, Minibatch Loss:0.0097, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-2181
# Optimization Iteration:   2181, Minibatch Loss:0.0725, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8% *
# predicted classes for validation-set:
# Optimization Iteration:   2201, Minibatch Loss:0.0265, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   2221, Minibatch Loss:0.0113, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   2241, Minibatch Loss:0.0676, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2261, Minibatch Loss:0.0075, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-2281
# Optimization Iteration:   2281, Minibatch Loss:0.1680, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.0% *
# predicted classes for validation-set:
# Optimization Iteration:   2301, Minibatch Loss:0.0621, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   2321, Minibatch Loss:0.0177, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2341, Minibatch Loss:0.0161, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2361, Minibatch Loss:0.0296, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2381, Minibatch Loss:0.0743, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2401, Minibatch Loss:0.0072, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   2421, Minibatch Loss:0.0396, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2441, Minibatch Loss:0.0094, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2461, Minibatch Loss:0.0526, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2481, Minibatch Loss:0.0111, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2501, Minibatch Loss:0.0134, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   2521, Minibatch Loss:0.0490, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2541, Minibatch Loss:0.0476, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2561, Minibatch Loss:0.0669, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2581, Minibatch Loss:0.0229, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2601, Minibatch Loss:0.0289, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   2621, Minibatch Loss:0.0809, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2641, Minibatch Loss:0.0078, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-2661
# Optimization Iteration:   2661, Minibatch Loss:0.1574, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.1% *
# predicted classes for validation-set:
# Optimization Iteration:   2681, Minibatch Loss:0.1201, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.5%
# predicted classes for validation-set:
# Optimization Iteration:   2701, Minibatch Loss:0.0066, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2721, Minibatch Loss:0.0213, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   2741, Minibatch Loss:0.0054, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2761, Minibatch Loss:0.0074, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2781, Minibatch Loss:0.0258, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-2801
# Optimization Iteration:   2801, Minibatch Loss:0.0229, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1% *
# predicted classes for validation-set:
# Optimization Iteration:   2821, Minibatch Loss:0.0055, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2841, Minibatch Loss:0.0104, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   2861, Minibatch Loss:0.0582, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   2881, Minibatch Loss:0.0073, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   2901, Minibatch Loss:0.0067, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   2921, Minibatch Loss:0.1087, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.4%
# predicted classes for validation-set:
# Optimization Iteration:   2941, Minibatch Loss:0.0598, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   2961, Minibatch Loss:0.0386, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   2981, Minibatch Loss:0.0039, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3001, Minibatch Loss:0.0157, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3021, Minibatch Loss:0.0122, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   3041, Minibatch Loss:0.0065, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3061, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3081, Minibatch Loss:0.0369, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3101, Minibatch Loss:0.0114, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3121, Minibatch Loss:0.0148, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3141, Minibatch Loss:0.1430, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3161, Minibatch Loss:0.0262, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   3181, Minibatch Loss:0.0075, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3201, Minibatch Loss:0.0438, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3221, Minibatch Loss:0.0080, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3241, Minibatch Loss:0.0057, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   3261, Minibatch Loss:0.0540, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.1%
# predicted classes for validation-set:
# Optimization Iteration:   3281, Minibatch Loss:0.0107, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3301, Minibatch Loss:0.0117, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-3321
# Optimization Iteration:   3321, Minibatch Loss:0.0051, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2% *
# predicted classes for validation-set:
# Optimization Iteration:   3341, Minibatch Loss:0.0022, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3361, Minibatch Loss:0.0158, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3381, Minibatch Loss:0.0090, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3401, Minibatch Loss:0.0216, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3421, Minibatch Loss:0.0262, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3441, Minibatch Loss:0.0066, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   3461, Minibatch Loss:0.0022, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3481, Minibatch Loss:0.0367, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3501, Minibatch Loss:0.0048, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3521, Minibatch Loss:0.0107, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3541, Minibatch Loss:0.0129, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3561, Minibatch Loss:0.0434, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3581, Minibatch Loss:0.0238, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-3601
# Optimization Iteration:   3601, Minibatch Loss:0.0256, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2% *
# predicted classes for validation-set:
# Optimization Iteration:   3621, Minibatch Loss:0.0203, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3641, Minibatch Loss:0.0185, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3661, Minibatch Loss:0.0077, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3681, Minibatch Loss:0.0194, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3701, Minibatch Loss:0.0130, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   3721, Minibatch Loss:0.0054, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3741, Minibatch Loss:0.0263, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3761, Minibatch Loss:0.0116, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3781, Minibatch Loss:0.0208, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   3801, Minibatch Loss:0.0110, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3821, Minibatch Loss:0.0119, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3841, Minibatch Loss:0.0237, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   3861, Minibatch Loss:0.0292, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3881, Minibatch Loss:0.0196, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3901, Minibatch Loss:0.0733, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   3921, Minibatch Loss:0.0168, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   3941, Minibatch Loss:0.0389, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   3961, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   3981, Minibatch Loss:0.0047, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4001, Minibatch Loss:0.0017, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4021, Minibatch Loss:0.0135, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   4041, Minibatch Loss:0.0038, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   4061, Minibatch Loss:0.0330, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   4081, Minibatch Loss:0.0061, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4101, Minibatch Loss:0.0168, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   4121, Minibatch Loss:0.0395, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4141, Minibatch Loss:0.0019, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4161, Minibatch Loss:0.0083, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4181, Minibatch Loss:0.0089, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4201, Minibatch Loss:0.0208, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4221, Minibatch Loss:0.0143, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.6%
# predicted classes for validation-set:
# Optimization Iteration:   4241, Minibatch Loss:0.0429, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4261, Minibatch Loss:0.0079, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4281, Minibatch Loss:0.0007, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4301, Minibatch Loss:0.0400, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4321, Minibatch Loss:0.0163, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4341, Minibatch Loss:0.0185, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4361, Minibatch Loss:0.0600, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4381, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4401, Minibatch Loss:0.0172, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4421, Minibatch Loss:0.0039, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   4441, Minibatch Loss:0.0076, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4461, Minibatch Loss:0.0150, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4481, Minibatch Loss:0.0077, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   4501, Minibatch Loss:0.0027, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-4521
# Optimization Iteration:   4521, Minibatch Loss:0.0227, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.3% *
# predicted classes for validation-set:
# Optimization Iteration:   4541, Minibatch Loss:0.0031, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4561, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4581, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   4601, Minibatch Loss:0.0064, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4621, Minibatch Loss:0.0823, Training-Batch Accuracy:  95.3%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4641, Minibatch Loss:0.0112, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4661, Minibatch Loss:0.0013, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4681, Minibatch Loss:0.0245, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   4701, Minibatch Loss:0.0040, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   4721, Minibatch Loss:0.0231, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4741, Minibatch Loss:0.0048, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4761, Minibatch Loss:0.0268, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4781, Minibatch Loss:0.0450, Training-Batch Accuracy:  96.9%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4801, Minibatch Loss:0.0678, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4821, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4841, Minibatch Loss:0.0032, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4861, Minibatch Loss:0.0086, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4881, Minibatch Loss:0.0451, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   4901, Minibatch Loss:0.0069, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4921, Minibatch Loss:0.0517, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   4941, Minibatch Loss:0.0229, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   4961, Minibatch Loss:0.0583, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   4981, Minibatch Loss:0.0065, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5001, Minibatch Loss:0.0228, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5021, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5041, Minibatch Loss:0.0130, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5061, Minibatch Loss:0.0204, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5081, Minibatch Loss:0.0046, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5101, Minibatch Loss:0.0014, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5121, Minibatch Loss:0.0038, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5141, Minibatch Loss:0.0173, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5161, Minibatch Loss:0.0082, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5181, Minibatch Loss:0.0055, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5201, Minibatch Loss:0.0221, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5221, Minibatch Loss:0.0100, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5241, Minibatch Loss:0.0278, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5261, Minibatch Loss:0.0066, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5281, Minibatch Loss:0.0127, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5301, Minibatch Loss:0.0122, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5321, Minibatch Loss:0.0017, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5341, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5361, Minibatch Loss:0.0098, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5381, Minibatch Loss:0.0017, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5401, Minibatch Loss:0.0017, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5421, Minibatch Loss:0.0044, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5441, Minibatch Loss:0.0215, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5461, Minibatch Loss:0.0231, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5481, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5501, Minibatch Loss:0.0105, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5521, Minibatch Loss:0.0023, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5541, Minibatch Loss:0.0115, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5561, Minibatch Loss:0.0087, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5581, Minibatch Loss:0.0160, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5601, Minibatch Loss:0.0265, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5621, Minibatch Loss:0.0007, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5641, Minibatch Loss:0.0134, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5661, Minibatch Loss:0.0065, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5681, Minibatch Loss:0.0143, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5701, Minibatch Loss:0.0071, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   5721, Minibatch Loss:0.0046, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5741, Minibatch Loss:0.0290, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   5761, Minibatch Loss:0.0057, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5781, Minibatch Loss:0.0122, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5801, Minibatch Loss:0.0154, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5821, Minibatch Loss:0.0213, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5841, Minibatch Loss:0.0025, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5861, Minibatch Loss:0.0022, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   5881, Minibatch Loss:0.0048, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5901, Minibatch Loss:0.0133, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5921, Minibatch Loss:0.0020, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5941, Minibatch Loss:0.0528, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   5961, Minibatch Loss:0.0008, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   5981, Minibatch Loss:0.0305, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6001, Minibatch Loss:0.0145, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6021, Minibatch Loss:0.0029, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6041, Minibatch Loss:0.0241, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6061, Minibatch Loss:0.1105, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6081, Minibatch Loss:0.0043, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6101, Minibatch Loss:0.0016, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.7%
# predicted classes for validation-set:
# Optimization Iteration:   6121, Minibatch Loss:0.0023, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6141, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6161, Minibatch Loss:0.0135, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6181, Minibatch Loss:0.0089, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6201, Minibatch Loss:0.0007, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6221, Minibatch Loss:0.0011, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6241, Minibatch Loss:0.0060, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6261, Minibatch Loss:0.0030, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6281, Minibatch Loss:0.0023, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6301, Minibatch Loss:0.0013, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6321, Minibatch Loss:0.0463, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6341, Minibatch Loss:0.0119, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6361, Minibatch Loss:0.0082, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6381, Minibatch Loss:0.0102, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6401, Minibatch Loss:0.0045, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6421, Minibatch Loss:0.0211, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6441, Minibatch Loss:0.0036, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6461, Minibatch Loss:0.0055, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6481, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6501, Minibatch Loss:0.0021, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6521, Minibatch Loss:0.0028, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6541, Minibatch Loss:0.0006, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6561, Minibatch Loss:0.0113, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6581, Minibatch Loss:0.0032, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6601, Minibatch Loss:0.0039, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-6621
# Optimization Iteration:   6621, Minibatch Loss:0.0075, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3% *
# predicted classes for validation-set:
# Optimization Iteration:   6641, Minibatch Loss:0.0052, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6661, Minibatch Loss:0.0020, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   6681, Minibatch Loss:0.0063, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   6701, Minibatch Loss:0.0076, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6721, Minibatch Loss:0.0095, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6741, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6761, Minibatch Loss:0.0021, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6781, Minibatch Loss:0.0037, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6801, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   6821, Minibatch Loss:0.0028, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6841, Minibatch Loss:0.1138, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.8%
# predicted classes for validation-set:
# Optimization Iteration:   6861, Minibatch Loss:0.0027, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   6881, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6901, Minibatch Loss:0.0030, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   6921, Minibatch Loss:0.0313, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   6941, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   6961, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   6981, Minibatch Loss:0.0052, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   7001, Minibatch Loss:0.0016, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   7021, Minibatch Loss:0.0026, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   7041, Minibatch Loss:0.0147, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# ...
# predicted classes for validation-set:
# Optimization Iteration:   7941, Minibatch Loss:0.0629, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   7961, Minibatch Loss:0.0016, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   7981, Minibatch Loss:0.0036, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8001, Minibatch Loss:0.0003, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8021, Minibatch Loss:0.0043, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8041, Minibatch Loss:0.0082, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8061, Minibatch Loss:0.0599, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8081, Minibatch Loss:0.0023, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   8101, Minibatch Loss:0.0015, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8121, Minibatch Loss:0.0024, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   8141, Minibatch Loss:0.0009, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8161, Minibatch Loss:0.0136, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8181, Minibatch Loss:0.0188, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8201, Minibatch Loss:0.0020, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8221, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   8241, Minibatch Loss:0.0080, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   8261, Minibatch Loss:0.0039, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8281, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8301, Minibatch Loss:0.0014, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8321, Minibatch Loss:0.0606, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8341, Minibatch Loss:0.0614, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   8361, Minibatch Loss:0.0042, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8381, Minibatch Loss:0.0020, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8401, Minibatch Loss:0.0078, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8421, Minibatch Loss:0.0283, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8441, Minibatch Loss:0.0043, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# model_path: checkpoints/model.ckpt
# Model saved in file: checkpoints/model.ckpt-8461
# Optimization Iteration:   8461, Minibatch Loss:0.0070, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3% *
# predicted classes for validation-set:
# Optimization Iteration:   8481, Minibatch Loss:0.0002, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8501, Minibatch Loss:0.0036, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8521, Minibatch Loss:0.0020, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8541, Minibatch Loss:0.0004, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8561, Minibatch Loss:0.0056, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8581, Minibatch Loss:0.0045, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   8601, Minibatch Loss:0.0115, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8621, Minibatch Loss:0.0575, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8641, Minibatch Loss:0.0056, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8661, Minibatch Loss:0.0015, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8681, Minibatch Loss:0.0016, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8701, Minibatch Loss:0.0470, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   8721, Minibatch Loss:0.0003, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8741, Minibatch Loss:0.0330, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8761, Minibatch Loss:0.0266, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8781, Minibatch Loss:0.0229, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8801, Minibatch Loss:0.0003, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8821, Minibatch Loss:0.0006, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8841, Minibatch Loss:0.0068, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8861, Minibatch Loss:0.0002, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8881, Minibatch Loss:0.0087, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   8901, Minibatch Loss:0.0004, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   8921, Minibatch Loss:0.0003, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   8941, Minibatch Loss:0.0004, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8961, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   8981, Minibatch Loss:0.0013, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9001, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   9021, Minibatch Loss:0.0000, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9041, Minibatch Loss:0.0180, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9061, Minibatch Loss:0.0013, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9081, Minibatch Loss:0.0034, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   9101, Minibatch Loss:0.0307, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   9121, Minibatch Loss:0.0254, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9141, Minibatch Loss:0.0001, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9161, Minibatch Loss:0.0040, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9181, Minibatch Loss:0.0015, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9201, Minibatch Loss:0.0451, Training-Batch Accuracy:  98.4%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   9221, Minibatch Loss:0.0270, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9241, Minibatch Loss:0.0034, Training-Batch Accuracy: 100.0%, Validation Accuracy: 98.9%
# predicted classes for validation-set:
# Optimization Iteration:   9261, Minibatch Loss:0.0547, Training-Batch Accuracy:  96.9%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9281, Minibatch Loss:0.0010, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9301, Minibatch Loss:0.0071, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9321, Minibatch Loss:0.0042, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9341, Minibatch Loss:0.0519, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9361, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9381, Minibatch Loss:0.0046, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9401, Minibatch Loss:0.0038, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9421, Minibatch Loss:0.0025, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9441, Minibatch Loss:0.0012, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9461, Minibatch Loss:0.0005, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9481, Minibatch Loss:0.0476, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9501, Minibatch Loss:0.0070, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9521, Minibatch Loss:0.0025, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9541, Minibatch Loss:0.0029, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9561, Minibatch Loss:0.0002, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9581, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9601, Minibatch Loss:0.0022, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.0%
# predicted classes for validation-set:
# Optimization Iteration:   9621, Minibatch Loss:0.0033, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   9641, Minibatch Loss:0.0018, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9661, Minibatch Loss:0.0534, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9681, Minibatch Loss:0.0058, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9701, Minibatch Loss:0.0044, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9721, Minibatch Loss:0.0199, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9741, Minibatch Loss:0.0629, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9761, Minibatch Loss:0.0602, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   9781, Minibatch Loss:0.0046, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9801, Minibatch Loss:0.0032, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   9821, Minibatch Loss:0.0152, Training-Batch Accuracy:  98.4%, Validation Accuracy: 99.1%
# predicted classes for validation-set:
# Optimization Iteration:   9841, Minibatch Loss:0.0090, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9861, Minibatch Loss:0.0038, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9881, Minibatch Loss:0.0126, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9901, Minibatch Loss:0.0011, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9921, Minibatch Loss:0.0015, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9941, Minibatch Loss:0.0008, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.3%
# predicted classes for validation-set:
# Optimization Iteration:   9961, Minibatch Loss:0.0008, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# predicted classes for validation-set:
# Optimization Iteration:   9981, Minibatch Loss:0.0081, Training-Batch Accuracy: 100.0%, Validation Accuracy: 99.2%
# Time usage:0:02:23
# 'checkpoints/model.ckpt-8461'

# %%
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:99.1% (9912 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[ 976    0    0    0    0    0    1    0    2    1]
#  [   0 1128    0    0    0    0    1    1    5    0]
#  [   2    0 1020    1    1    0    0    6    2    0]
#  [   0    1    0 1001    0    5    0    0    3    0]
#  [   0    0    1    0  975    0    2    0    0    4]
#  [   2    0    0    3    0  882    1    1    2    1]
#  [   2    2    0    0    0    3  946    0    4    1]
#  [   0    1    3    2    0    0    0 1017    1    4]
#  [   1    0    0    2    0    2    0    0  968    1]
#  [   1    0    0    0    4    3    0    2    0  999]]
# ------------------------------------------------------------------------------------

# %% [markdown]
# #### Saver

# %%
# reinitialize all the Variables of NN with random values
init_variables()

# %%
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:11.4% (1137 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[  2  28   1   0   8   1 194   5   3 738]
#  [  3 163   0   0   0   3 299   3   3 661]
#  [  0  48   0   1   3   3 148   4   5 820]
#  [  1  59   0   0   1   8 238   4   5 694]
#  [  1  35   0   0   1  14 173   2   0 756]
#  [  2  44   0   0   2  10 254   2   2 576]
#  [  1  77   0   0   1   4 193   0   3 679]
#  [  7  32   0   1   2   7 288   2   2 687]
#  [  5  57   0   0   0  11 213   0   3 685]
#  [  3  40   0   0   0  11 191   0   1 763]]
# ------------------------------------------------------------------------------------

# %%
# reload all the variables that were saved to file during optimization
# get the latest model which has been saved
model_file = tf.train.latest_checkpoint('checkpoints/')
saver.restore(sess=session, save_path=model_file)
print("Model restored from file: %s" %model_file)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/model.ckpt-961
# Model restored from file: checkpoints/model.ckpt-961

# %%
print_test_accuracy(tf_session=session,
                    x_ph=x,
                    y_true_ph=y_true,
                    keep_prob_ph=keep_prob,
                    y_pred_cls_tensor=y_pred_cls,
                    show_confusion_matrix=True)
# Out:
# predicted classes for test-set:
# Accuracy on Test-set:98.1% (9807 / 10000)
# Confusion Matrix for test-set :
# Confusion Matrix:
#  [[ 962    0    2    0    0    1    8    1    3    3]
#  [   0 1127    2    1    1    1    0    1    2    0]
#  [   4    2 1012    3    0    0    0    2    9    0]
#  [   0    0    0 1002    0    1    0    4    3    0]
#  [   0    1    3    1  967    0    1    0    2    7]
#  [   2    0    2   16    0  863    2    2    3    2]
#  [   5    2    0    1    5    2  941    0    2    0]
#  [   0    3   14    3    0    1    0 1004    1    2]
#  [   3    1    5    1    4    2    2    1  951    4]
#  [   1    5    1    5    9    2    0    6    2  978]]
# ------------------------------------------------------------------------------------

# %%
# close the session
# session.close()

# %% [markdown]
# visualizing the TF graph

# %%
# writer = tf.summary.FileWriter("tmp/simple_cnn/3")
# writer.add_graph(session.graph)

# in you commande line console, just write it down
# tensorboard --logdir ./tmp/simple_cnn/2

# %% [markdown]
# feature visualisation

# %%
from modules.feature_visualization import get_conv_layer_names

conv_names = get_conv_layer_names()
print("conv_names:", conv_names)
print("number of convolution layer:", len(conv_names))
# Out:
# conv_names: ['layer_conv_1/conv2d', 'layer_conv_2/conv2d']
# number of convolution layer: 2

# %%
import numpy as np

logits = output_layer

def optimize_image(conv_id=None, feature=0,
                   num_iterations=30, show_progress=True):
    """
    Find an image that maximizes the feature
    given by the conv_id and feature number.

    Parameters:
    conv_id: Integer identifying the convolutional layer to
             maximize. It is an index into conv_names.
             If None then use the last fully-connected layer
             before the softmax output.
    feature: Index into the layer for the feature to maximize.
    num_iteration: Number of optimization iterations to perform.
    show_progress: Boolean whether to show the progress.
    """

    # Create the loss-function that must be maximized.
    if conv_id is None:
        # If we want to maximize a feature on the last layer,
        # then we use the fully-connected layer prior to the
        # softmax-classifier. The feature no. is the class-number
        # and must be an integer between 1 and 1000.
        # The loss-function is just the value of that feature.
        loss = tf.reduce_mean(logits[:, feature])
    else:
        # If instead we want to maximize a feature of a
        # convolutional layer inside the neural network.

        # Get the name of the convolutional operator.
        conv_name = conv_names[conv_id]
        
        # Get the default TensorFlow graph.
        graph = tf.get_default_graph()
        
        # Get a reference to the tensor that is output by the
        # operator. Note that ":0" is added to the name for this.
        tensor = graph.get_tensor_by_name(conv_name + ":0")

        # The loss-function is the average of all the
        # tensor-values for the given feature. This
        # ensures that we generate the whole input image.
        # You can try and modify this so it only uses
        # a part of the tensor.
        loss = tf.reduce_mean(tensor[:,:,:,feature])

    # Get the gradient for the loss-function with regard to
    # the input image. This creates a mathematical
    # function for calculating the gradient.
    gradient = tf.gradients(loss, x_image)

    # Generate a random image of the same size as the raw input.
    # Each pixel is a small random value between 0.45 and 0.55,
    # which is the middle of the valid range between 0 and 1.
    image = 0.1 * np.random.uniform(size=img_shape) + 0.45

    # Perform a number of optimization iterations to find
    # the image that maximizes the loss-function.
    for i in range(num_iterations):
        # Reshape the array so it is a 4-rank tensor.
        img_reshaped = image[np.newaxis,:,:,np.newaxis]

        # Create a feed-dict for inputting the image to the graph.
        feed_dict = {x_image: img_reshaped}

        # Calculate the predicted class-scores,
        # as well as the gradient and the loss-value.
        pred, grad, loss_value = session.run([y_pred, gradient, loss],
                                             feed_dict=feed_dict)
        
        # Squeeze the dimensionality for the gradient-array.
        grad = np.array(grad).squeeze()

        # The gradient now tells us how much we need to change the
        # input image in order to maximize the given feature.

        # Calculate the step-size for updating the image.
        # This step-size was found to give fast convergence.
        # The addition of 1e-8 is to protect from div-by-zero.
        step_size = 1.0 / (grad.std() + 1e-8)

        # Update the image by adding the scaled gradient
        # This is called gradient ascent.
        image += step_size * grad

        # Ensure all pixel-values in the image are between 0 and 1.
        image = np.clip(image, 0.0, 1.0)

        if show_progress:
            print("Iteration:", i)

            # Convert the predicted class-scores to a one-dim array.
            pred = np.squeeze(pred)

            # The predicted class for the Inception model.
            pred_cls = np.argmax(pred)

            # The score (probability) for the predicted class.
            cls_score = pred[pred_cls]

            # Print the predicted score etc.
            msg = "Predicted class: {0}, score: {1:>7.2%}"
            print(msg.format(pred_cls, cls_score))

            # Print statistics for the gradient.
            msg = "Gradient min: {0:>9.6f}, max: {1:>9.6f}, stepsize: {2:>9.2f}"
            print(msg.format(grad.min(), grad.max(), step_size))

            # Print the loss-value.
            print("Loss:", loss_value)

            # Newline.
            print()

    return image.squeeze()

# %%
from modules.plot_functions import plot_images_10

def optimize_images(conv_id=None, num_iterations=30):
    """
    Find 10 images that maximize the 10 first features in the layer
    given by the conv_id.
    
    Parameters:
    conv_id: Integer identifying the convolutional layer to
             maximize. It is an index into conv_names.
             If None then use the last layer before the softmax output.
    num_iterations: Number of optimization iterations to perform.
    """

    # Which layer are we using?
    if conv_id is None:
        print("Final fully-connected layer before softmax.")
    else:
        print("Layer:", conv_names[conv_id])

    # Initialize the array of images.
    images = []

    # For each feature do the following.
    for feature in range(0,10):
        print("Optimizing image for feature no.", feature)
        
        # Find the image that maximizes the given feature
        # for the network layer identified by conv_id (or None).
        image = optimize_image(conv_id=conv_id, feature=feature,
                               show_progress=False,
                               num_iterations=num_iterations)

        # Squeeze the dim of the array.
        image = image.squeeze()

        # Append to the list of images.
        images.append(image)

    # Convert to numpy-array so we can index all dimensions easily.
    images = np.array(images)

    # Plot the images.
    plot_images_10(images=images)

# %%
from modules.feature_visualization import optimize_images

# %%
optimize_images(tf_session=session,
                x_image = x_image,
                y_pred = y_pred,
                logits = output_layer,
                conv_names=conv_names,
                conv_id=0)
# Out:
# Layer: layer_conv_1/conv2d
# Optimizing image for feature No. 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-265cc58d93c7> in <module>
#       5                 logits = output_layer,
#       6                 conv_names=conv_names,
# ----> 7                 conv_id=0)
#
# ~/Workspace/tensorflow_tutoral/Test/modules/feature_visualization.py in optimize_images(tf_session, x_image, y_pred, logits, conv_names, conv_id, num_iterations)
#     200                                feature=feature,
#     201                                show_progress=False,
# --> 202                                num_iterations=num_iterations)
#     203
#     204         # squeeze the dimension of the array
#
# ~/Workspace/tensorflow_tutoral/Test/modules/feature_visualization.py in optimize_image(tf_session, x_image, y_pred, logits, conv_names, conv_id, feature, num_iterations, show_progress)
#      77         # get a reference to the tensor that is output by the operator.
#      78         # Note that ":0" is added to the name for this.
# ---> 79         tensor = graph.get_tensor_by_name(conv_name + ":0")
#      80
#      81         # the loss-function is the average of all the tensor-values
#
# NameError: name 'conv_name' is not defined

# %%
optimize_images(conv_id=1)
# Out:
# Layer: layer_conv_2/conv2d
# Optimizing image for feature no. 0
# Optimizing image for feature no. 1
# Optimizing image for feature no. 2
# Optimizing image for feature no. 3
# Optimizing image for feature no. 4
# Optimizing image for feature no. 5
# Optimizing image for feature no. 6
# Optimizing image for feature no. 7
# Optimizing image for feature no. 8
# Optimizing image for feature no. 9

# %%
image = optimize_image(conv_id=None, feature=2,
                       num_iterations=10, show_progress=True)
# Out:
# Iteration: 0
# Predicted class: 3, score:  74.39%
# Gradient min: -1.029678, max:  1.139306, stepsize:      3.11
# Loss: 0.8730679
#
# Iteration: 1
# Predicted class: 2, score: 100.00%
# Gradient min: -1.768076, max:  1.793221, stepsize:      2.86
# Loss: 18.120108
#
# Iteration: 2
# Predicted class: 2, score: 100.00%
# Gradient min: -1.878758, max:  1.173213, stepsize:      3.00
# Loss: 39.60351
#
# Iteration: 3
# Predicted class: 2, score: 100.00%
# Gradient min: -2.068837, max:  0.903694, stepsize:      3.13
# Loss: 37.98139
#
# Iteration: 4
# Predicted class: 2, score: 100.00%
# Gradient min: -2.257016, max:  1.353005, stepsize:      2.85
# Loss: 46.540264
#
# Iteration: 5
# Predicted class: 2, score: 100.00%
# Gradient min: -1.588544, max:  0.817387, stepsize:      3.59
# Loss: 35.031216
#
# Iteration: 6
# Predicted class: 2, score: 100.00%
# Gradient min: -2.027380, max:  1.254303, stepsize:      2.74
# Loss: 48.569157
#
# Iteration: 7
# Predicted class: 2, score: 100.00%
# Gradient min: -1.734093, max:  0.888885, stepsize:      2.97
# Loss: 44.578903
#
# Iteration: 8
# Predicted class: 2, score: 100.00%
# Gradient min: -2.144853, max:  1.180065, stepsize:      2.74
# Loss: 45.75204
#
# Iteration: 9
# Predicted class: 2, score: 100.00%
# Gradient min: -1.923217, max:  0.891336, stepsize:      3.39
# Loss: 33.217815

# %%
from modules.plot_functions import plot_image
plot_image(image)

# %%
optimize_images(conv_id=None)
# Out:
# Final fully-connected layer before softmax.
# Optimizing image for feature no. 0
# Optimizing image for feature no. 1
# Optimizing image for feature no. 2
# Optimizing image for feature no. 3
# Optimizing image for feature no. 4
# Optimizing image for feature no. 5
# Optimizing image for feature no. 6
# Optimizing image for feature no. 7
# Optimizing image for feature no. 8
# Optimizing image for feature no. 9

# %%
# session.close()
